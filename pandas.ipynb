# %%
# pandas is used for data science and data analysis

# pivot function

# %%
import pandas as pd


students = []
marks = []
math = []
physics = []
chemistry = []
obtained_marks = []
total_marks = 100
percentages = []
grade = []

for i in range(2):

  student = input("Enter the student name")
  math1 = int(input("Enter the student marks in math"))
  physics1 = int(input("Enter the student marks in physics"))
  chemistry1 = int(input("Enter the student marks in chemistry"))
  

  students = [math, physics,chemistry]
  





  students.append(student)
  math.append(math1)
  physics.append(physics1)
  chemistry.append(chemistry1)
  
  obtain_marks = math1 + physics1 + chemistry1
  #percentage = (obtained_marks / total_marks) * 100
  percentage = total_marks * 100 / 300
  percentages.append(percentage)

  def find_percentage(percent):

   if percentages >= 90:
    grade.append('A+')
   elif percentages >= 80:
    grade.append('A')
   elif percentages >= 70:
    grade.append('B')
   elif percentages >= 60:
    grade.append('C')
   elif percentages <= 50:
    grade.append('Fail')


  obtained_marks.append(obtain_marks)
  #percentage1.append(percentage)
  






df = pd.DataFrame({'student name': student, 'math marks': math1, 'physics marks': physics1, 'chemistiry marks': chemistry1, 'obtained_marks': obtained_marks, 'percentage': percentages, 'grade': grade})
print(df)

#df.to_excel(r'D:\NAVTTAC Code/sdata.xlsx', index= False)













#df = pd.DataFrame({'name': "",      })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 62
#      53   obtained_marks.append(obtain_marks)
#      54   #percentage1.append(percentage)
# ---> 62 df = pd.DataFrame({'student name': student, 'math marks': math1, 'physics marks': physics1, 'chemistiry marks': chemistry1, 'obtained_marks': obtained_marks, 'percentage': percentages, 'grade': grade})
#      63 print(df)
#      65 #df.to_excel(r'D:\NAVTTAC Code/sdata.xlsx', index= False)
#      66
#      67
#    (...)
#      78
#      79 #df = pd.DataFrame({'name': "",      })
#
# File c:\Users\Jamshaid\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:736, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     730     mgr = self._init_mgr(
#     731         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     732     )
# ...
